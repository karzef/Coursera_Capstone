# %%
import numpy as np
import pandas as pd
import json
from geopy.geocoders import Nominatim 
import requests
from pandas.io.json import json_normalize 
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# # 1. Build Toronto Postal Codes Dataframe

# %%
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

# %% [markdown]
# ### Extract Wikipedia table using Beautiful Soup

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(website_url,'lxml')
#Build table object
My_table = soup.find('table',{'class':'wikitable sortable'})
whole_list=My_table.findAll("tr")
postalcode=[]
borough=[]
neighborhood=[]

# %% [markdown]
# ### Loop to copy and paste each beautiful soup cell object into lists|

# %%
i=0
for tr in My_table.findAll("tr"):
    sub_list=whole_list[i].findAll("td")
    if sub_list :
            postalcode.append(sub_list[0].get_text())
            borough.append(sub_list[1].get_text()) 
            spec_list=sub_list[2].string
            if spec_list!="Not assigned\n" :
                    spec_list=sub_list[2].findAll("a")
                    if spec_list :
                        neighborhood.append(spec_list[0].get('title'))
                    else:
                        neighborhood.append(sub_list[2].get_text().strip()) 
            else:
                    neighborhood.append(sub_list[2].get_text().strip())
    i=i+1

# %% [markdown]
# ### Create and format dataframe from previous extracted data

# %%
#Create dataframe with data from previous 
df=pd.DataFrame()
df['PostalCode']=postalcode
df['Borough']=borough
df['Neighborhood']=neighborhood

#Remove from dataframe (Toronto) and ", Toronto"
df['Neighborhood']=df.loc[ : , 'Neighborhood' ].str.replace(r"\(.*\)","").str.replace(', Toronto','')

#Remove from dataframe "Not assigned" Borough rows
dt=df[df.Borough!= 'Not assigned']
dt = dt.reset_index(drop=True)

#Loop to copy Borough in "Not assigned" Neighborhood cells 
for idx, row in dt.iterrows():
    if dt['Neighborhood'].iloc[idx]=="Not assigned":
        dt.loc[idx,'Neighborhood']=dt.loc[idx,'Borough']

# %% [markdown]
# ### Return Toronto Postal Codes Dataframe combining together Neighborhood with same postal code

# %%
dt = dt.groupby(['PostalCode','Borough'])['Neighborhood'].apply(', '.join).reset_index()
dt.head(10)
# Out:
#   PostalCode      Borough                                     Neighborhood
# 0        M1B  Scarborough                                   Rouge, Malvern
# 1        M1C  Scarborough          Highland Creek , Rouge Hill, Port Union
# 2        M1E  Scarborough                Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                           Woburn
# 4        M1H  Scarborough                                           Woburn
# 5        M1J  Scarborough                              Scarborough Village
# 6        M1K  Scarborough      East Birchmount Park, Ionview, Kennedy Park
# 7        M1L  Scarborough                  Clairlea, Golden Mile, Oakridge
# 8        M1M  Scarborough  Cliffcrest, Cliffside, Scarborough Village West
# 9        M1N  Scarborough                      Birch Cliff, Cliffside West

# %%
dt.shape
# Out:
# (103, 3)

# %% [markdown]
# # 2. Add the Latitude and Longitude to Toronto Postal Codes Dataframe

# %% [markdown]
# ### Load geospatial csv , Geocoder Python package was not working

# %%
Toronto_Lat_Lon = pd.read_csv('http://cocl.us/Geospatial_data')
dt['Latitude'] = ''
dt['Longitude'] = ''

# %%
# !wget -q -O 'toronto.json' https://cocl.us/Geospatial_data
print('Data downloaded!')
# Out:
# /bin/sh: wget: command not found
# Data downloaded!

# %% [markdown]
# ### Function returning Latitude based on postal code

# %%
def Geosp_Lat(Coord):
    for idx, row in Toronto_Lat_Lon.iterrows():
        if Toronto_Lat_Lon['Postal Code'].iloc[idx]==Coord:
            Lat=Toronto_Lat_Lon.loc[idx,'Latitude']
            return Lat;

# %% [markdown]
# ### Function returning Longitude based on postal code

# %%
def Geosp_Lon(Coord):
    for idx, row in Toronto_Lat_Lon.iterrows():
        if Toronto_Lat_Lon['Postal Code'].iloc[idx]==Coord:
            Lon=Toronto_Lat_Lon.loc[idx,'Longitude']
            return Lon;

# %% [markdown]
# ### Assign Latitude and Longitude to each postal code using previous functions

# %%
for idx, row in dt.iterrows():
    PC_toSearch=(dt['PostalCode'].iloc[idx])
    dt.loc[idx,'Latitude']=Geosp_Lat(PC_toSearch)
    dt.loc[idx,'Longitude']=Geosp_Lon(PC_toSearch)

# %%
dt.head()
# Out:
#   PostalCode      Borough                             Neighborhood Latitude  \
# 0        M1B  Scarborough                           Rouge, Malvern  43.8067
# 1        M1C  Scarborough  Highland Creek , Rouge Hill, Port Union  43.7845
# 2        M1E  Scarborough        Guildwood, Morningside, West Hill  43.7636
# 3        M1G  Scarborough                                   Woburn   43.771
# 4        M1H  Scarborough                                   Woburn  43.7731
#
#   Longitude
# 0  -79.1944
# 1  -79.1605
# 2  -79.1887
# 3  -79.2169
# 4  -79.2395

# %% [markdown]
# # 3.Build a Map of Toronto with markers

# %% [markdown]
# ### Return latitude, longitude of Toronto

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto, Ontario are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto, Ontario are 43.653963, -79.387207.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, PostalCode,borough in zip(dt['Latitude'], dt['Longitude'], dt['PostalCode'], dt['Borough']):
    label = '{}, {}'.format(PostalCode, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 4.Build a Map of Downtown Toronto with markers

# %% [markdown]
# ### Build Downtown Toronto dataframe

# %%
Downtown_Toronto_data=dt[dt['Borough'] == 'Downtown Toronto'].reset_index(drop=True)
Downtown_Toronto_data
# Out:
#    PostalCode           Borough  \
# 0         M4W  Downtown Toronto
# 1         M4X  Downtown Toronto
# 2         M4Y  Downtown Toronto
# 3         M5A  Downtown Toronto
# 4         M5B  Downtown Toronto
# 5         M5C  Downtown Toronto
# 6         M5E  Downtown Toronto
# 7         M5G  Downtown Toronto
# 8         M5H  Downtown Toronto
# 9         M5J  Downtown Toronto
# 10        M5K  Downtown Toronto
# 11        M5L  Downtown Toronto
# 12        M5S  Downtown Toronto
# 13        M5T  Downtown Toronto
# 14        M5V  Downtown Toronto
# 15        M5W  Downtown Toronto
# 16        M5X  Downtown Toronto
# 17        M6G  Downtown Toronto
#
#                                          Neighborhood Latitude Longitude
# 0                                            Rosedale  43.6796  -79.3775
# 1                         Cabbagetown, St. James Town   43.668  -79.3677
# 2                                Church and Wellesley  43.6659  -79.3832
# 3                          Harbourfront , Regent Park  43.6543  -79.3606
# 4                            Ryerson, Garden District  43.6572  -79.3789
# 5                                      St. James Town  43.6515  -79.3754
# 6                                         Berczy Park  43.6448  -79.3733
# 7                                  Central Bay Street   43.658  -79.3874
# 8                            Adelaide, King, Richmond  43.6506  -79.3846
# 9   Harbourfront East, Toronto Islands, Union Stat...  43.6408  -79.3818
# 10           Design Exchange, Toronto Dominion Centre  43.6472  -79.3816
# 11                     Commerce Court, Victoria Hotel  43.6482  -79.3798
# 12                     Harbord, University of Toronto  43.6627     -79.4
# 13         Chinatown, Grange Park , Kensington Market  43.6532     -79.4
# 14  CN Tower, Bathurst Quay, Island airport, Harbo...  43.6289  -79.3944
# 15                    Stn A PO Boxes 25 The Esplanade  43.6464  -79.3748
# 16             First Canadian Place, Underground city  43.6484  -79.3823
# 17                                           Christie  43.6695  -79.4226

# %% [markdown]
# ### Return latitude, longitude of Downtown Toronto

# %%
address = 'Downtown Toronto, Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.6541737, -79.3808116451341.

# %% [markdown]
# ### Create map of Downtown Toronto with markers using latitude and longitude values

# %%
map_DowntownToronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, PostalCode,borough in zip(Downtown_Toronto_data['Latitude'], Downtown_Toronto_data['Longitude'], Downtown_Toronto_data['PostalCode'], Downtown_Toronto_data['Borough']):
    label = '{}, {}'.format(PostalCode, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_DowntownToronto)  
    
map_DowntownToronto

# %% [markdown]
# # 5.Explore Downtown Toronto using foursquare

# %% [markdown]
# ### Foursquare user credentials

# %%
CLIENT_ID = '5DF0SUHJHNTIYJQZRRDQTPFZBF3L4MG1BPX14MUTWOGECNSQ' # your Foursquare ID
CLIENT_SECRET = 'BHAFZLAHSXXXUPUQJSY0OJISSCJOULN2KHHG41ORN0POBOUV' # your Foursquare Secret
VERSION = '20190104'
LIMIT = 100
radius=400

# %% [markdown]
# ### Function returning venues from Foursquare

# %%
 def getNearbyVenues(names, latitudes, longitudes, radius=300):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['PostalCode', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ### Building Downtown Toronto venues dataframe using previous function

# %%
DowntownToronto_venues = getNearbyVenues(names=Downtown_Toronto_data['PostalCode'],
                                   latitudes=Downtown_Toronto_data['Latitude'],
                                   longitudes=Downtown_Toronto_data['Longitude']
                                  )

# %%
DowntownToronto_venues.head()
# Out:
#   PostalCode  Neighborhood Latitude  Neighborhood Longitude  \
# 0        M4W              43.679563              -79.377529
# 1        M4W              43.679563              -79.377529
# 2        M4X              43.667967              -79.367675
# 3        M4X              43.667967              -79.367675
# 4        M4X              43.667967              -79.367675
#
#                           Venue  Venue Latitude  Venue Longitude  \
# 0  Park Drive Reservation Lands       43.679822       -79.377787
# 1               Mooredale House       43.678631       -79.380091
# 2                   Cranberries       43.667843       -79.369407
# 3        Butter Chicken Factory       43.667072       -79.369184
# 4                      F'Amelia       43.667536       -79.368613
#
#        Venue Category
# 0                Park
# 1            Building
# 2               Diner
# 3   Indian Restaurant
# 4  Italian Restaurant

# %% [markdown]
# ### Top 10 Downtown Toronto (by postal code) venues dataframe

# %%
# one hot encoding
DowntownToronto_onehot = pd.get_dummies(DowntownToronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add pc column back to dataframe
DowntownToronto_onehot['PostalCode'] = DowntownToronto_venues['PostalCode'] 

# move pc column to the first column
fixed_columns = [DowntownToronto_onehot.columns[-1]] + list(DowntownToronto_onehot.columns[:-1])
DowntownToronto_onehot = DowntownToronto_onehot[fixed_columns]

# %%
DowntownToronto_grouped = DowntownToronto_onehot.groupby('PostalCode').mean().reset_index()

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['PostalCode']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
PostalCode_venues_sorted = pd.DataFrame(columns=columns)
PostalCode_venues_sorted['PostalCode'] = DowntownToronto_grouped['PostalCode']

for ind in np.arange(DowntownToronto_grouped.shape[0]):
    PostalCode_venues_sorted.iloc[ind, 1:] = return_most_common_venues(DowntownToronto_grouped.iloc[ind, :], num_top_venues)

# %%
PostalCode_venues_sorted.head()
# Out:
#   PostalCode 1st Most Common Venue 2nd Most Common Venue  \
# 0        M4W                  Park              Building
# 1        M4X           Pizza Place           Coffee Shop
# 2        M4Y               Gay Bar          Burger Joint
# 3        M5A  Gym / Fitness Center            Food Truck
# 4        M5B           Coffee Shop                  Café
#
#        3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                Yoga Studio            Donut Shop           Fish Market
# 1                 Restaurant                  Café     Outdoor Sculpture
# 2        Japanese Restaurant           Coffee Shop             Nightclub
# 3             History Museum        Breakfast Spot                   Spa
# 4  Middle Eastern Restaurant        Clothing Store                 Hotel
#
#        6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0          Fish & Chips Shop  Fast Food Restaurant        Farmers Market
# 1        Japanese Restaurant               Butcher        Sandwich Place
# 2  Middle Eastern Restaurant    Mexican Restaurant                  Park
# 3                Coffee Shop              Bus Stop               Theater
# 4             Sandwich Place         Movie Theater              Tea Room
#
#     9th Most Common Venue 10th Most Common Venue
# 0    Ethiopian Restaurant    Dumpling Restaurant
# 1      Chinese Restaurant           Liquor Store
# 2             Men's Store  General Entertainment
# 3  Furniture / Home Store                 Bakery
# 4           Burrito Place             Restaurant

# %% [markdown]
# # 6.Run k-means to cluster Downtown Toronto Postal Codes into 5 clusters.

# %%
# set number of clusters
kclusters = 5

DowntownToronto_grouped_clustering = DowntownToronto_grouped.drop('PostalCode', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(DowntownToronto_grouped_clustering)

# %%
# add clustering labels
PostalCode_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

DowntownToronto_merged = Downtown_Toronto_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each pc
DowntownToronto_merged = DowntownToronto_merged.join(PostalCode_venues_sorted.set_index('PostalCode'), on='PostalCode')

DowntownToronto_merged.head()
# Out:
#   PostalCode           Borough                 Neighborhood Latitude  \
# 0        M4W  Downtown Toronto                     Rosedale  43.6796
# 1        M4X  Downtown Toronto  Cabbagetown, St. James Town   43.668
# 2        M4Y  Downtown Toronto         Church and Wellesley  43.6659
# 3        M5A  Downtown Toronto   Harbourfront , Regent Park  43.6543
# 4        M5B  Downtown Toronto     Ryerson, Garden District  43.6572
#
#   Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0  -79.3775               2                  Park              Building
# 1  -79.3677               1           Pizza Place           Coffee Shop
# 2  -79.3832               1               Gay Bar          Burger Joint
# 3  -79.3606               1  Gym / Fitness Center            Food Truck
# 4  -79.3789               1           Coffee Shop                  Café
#
#        3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                Yoga Studio            Donut Shop           Fish Market
# 1                 Restaurant                  Café     Outdoor Sculpture
# 2        Japanese Restaurant           Coffee Shop             Nightclub
# 3             History Museum        Breakfast Spot                   Spa
# 4  Middle Eastern Restaurant        Clothing Store                 Hotel
#
#        6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0          Fish & Chips Shop  Fast Food Restaurant        Farmers Market
# 1        Japanese Restaurant               Butcher        Sandwich Place
# 2  Middle Eastern Restaurant    Mexican Restaurant                  Park
# 3                Coffee Shop              Bus Stop               Theater
# 4             Sandwich Place         Movie Theater              Tea Room
#
#     9th Most Common Venue 10th Most Common Venue
# 0    Ethiopian Restaurant    Dumpling Restaurant
# 1      Chinese Restaurant           Liquor Store
# 2             Men's Store  General Entertainment
# 3  Furniture / Home Store                 Bakery
# 4           Burrito Place             Restaurant

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(DowntownToronto_merged['Latitude'], DowntownToronto_merged['Longitude'], DowntownToronto_merged['PostalCode'], DowntownToronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 7.Analyse Clusters

# %% [markdown]
# ### Cluster1 venue category shows evidence of residential area

# %%
DowntownToronto_merged.loc[DowntownToronto_merged['Cluster Labels'] == 0, DowntownToronto_merged.columns[[1] + list(range(5, DowntownToronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 17  Downtown Toronto               0         Grocery Store
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 17                  Café  Gym / Fitness Center           Coffee Shop
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 17           Candy Store           Yoga Studio            Donut Shop
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 17     Fish & Chips Shop  Fast Food Restaurant         Farmers Market

# %% [markdown]
# ###  The selective venue category for Cluster2 is Eateries

# %%
DowntownToronto_merged.loc[DowntownToronto_merged['Cluster Labels'] == 1, DowntownToronto_merged.columns[[1] + list(range(5, DowntownToronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 1   Downtown Toronto               1           Pizza Place
# 2   Downtown Toronto               1               Gay Bar
# 3   Downtown Toronto               1  Gym / Fitness Center
# 4   Downtown Toronto               1           Coffee Shop
# 5   Downtown Toronto               1           Coffee Shop
# 7   Downtown Toronto               1           Coffee Shop
# 8   Downtown Toronto               1            Steakhouse
# 9   Downtown Toronto               1           Coffee Shop
# 10  Downtown Toronto               1           Coffee Shop
# 11  Downtown Toronto               1           Coffee Shop
# 12  Downtown Toronto               1           Coffee Shop
# 13  Downtown Toronto               1    Chinese Restaurant
# 15  Downtown Toronto               1          Cocktail Bar
# 16  Downtown Toronto               1           Coffee Shop
#
#    2nd Most Common Venue      3rd Most Common Venue  4th Most Common Venue  \
# 1            Coffee Shop                 Restaurant                   Café
# 2           Burger Joint        Japanese Restaurant            Coffee Shop
# 3             Food Truck             History Museum         Breakfast Spot
# 4                   Café  Middle Eastern Restaurant         Clothing Store
# 5     Italian Restaurant                  Gastropub             Restaurant
# 7         Sandwich Place                       Café     Italian Restaurant
# 8       Asian Restaurant        American Restaurant            Coffee Shop
# 9                   Café                       Park                  Hotel
# 10         Deli / Bodega                 Restaurant                 Bakery
# 11            Restaurant                       Café          Deli / Bodega
# 12        Sandwich Place                       Café      French Restaurant
# 13                  Café                        Bar  Vietnamese Restaurant
# 15            Restaurant                        Pub     Italian Restaurant
# 16         Deli / Bodega                       Café     Seafood Restaurant
#
#             5th Most Common Venue      6th Most Common Venue  \
# 1               Outdoor Sculpture        Japanese Restaurant
# 2                       Nightclub  Middle Eastern Restaurant
# 3                             Spa                Coffee Shop
# 4                           Hotel             Sandwich Place
# 5                       BBQ Joint        Japanese Restaurant
# 7                   Deli / Bodega                        Spa
# 8             Japanese Restaurant         Seafood Restaurant
# 9                    Liquor Store             Sandwich Place
# 10                           Café        American Restaurant
# 11                          Hotel                  Gastropub
# 12                            Pub                  Bookstore
# 13  Vegetarian / Vegan Restaurant             Ice Cream Shop
# 15                          Hotel                Coffee Shop
# 16                    Salad Place                 Restaurant
#
#    7th Most Common Venue       8th Most Common Venue   9th Most Common Venue  \
# 1                Butcher              Sandwich Place      Chinese Restaurant
# 2     Mexican Restaurant                        Park             Men's Store
# 3               Bus Stop                     Theater  Furniture / Home Store
# 4          Movie Theater                    Tea Room           Burrito Place
# 5                  Hotel                 Yoga Studio             Pizza Place
# 7              Bookstore  Modern European Restaurant         Thai Restaurant
# 8                    Bar             Thai Restaurant                    Café
# 9             Restaurant               Boat or Ferry              Sports Bar
# 10       Thai Restaurant                 Salad Place  Gluten-free Restaurant
# 11           Salad Place                Burger Joint              Steakhouse
# 12   Japanese Restaurant          Italian Restaurant                  Bakery
# 13          Noodle House        Caribbean Restaurant                Tea Room
# 15        Breakfast Spot                    Beer Bar     Moroccan Restaurant
# 16   American Restaurant                         Bar               Gastropub
#
#            10th Most Common Venue
# 1                    Liquor Store
# 2           General Entertainment
# 3                          Bakery
# 4                      Restaurant
# 5           Performing Arts Venue
# 7                   Smoothie Shop
# 8                     Pizza Place
# 9              Italian Restaurant
# 10             Chinese Restaurant
# 11                         Bakery
# 12  Vegetarian / Vegan Restaurant
# 13        Comfort Food Restaurant
# 15                        Theater
# 16                   Burger Joint

# %% [markdown]
# ###  The selective venue category for Cluster3 is Parks

# %%
DowntownToronto_merged.loc[DowntownToronto_merged['Cluster Labels'] == 2, DowntownToronto_merged.columns[[1] + list(range(5, DowntownToronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 0  Downtown Toronto               2                  Park
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0              Building           Yoga Studio            Donut Shop
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0           Fish Market     Fish & Chips Shop  Fast Food Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0        Farmers Market  Ethiopian Restaurant    Dumpling Restaurant

# %% [markdown]
# ###  The selective venue category for Cluster4 is Airport

# %%
DowntownToronto_merged.loc[DowntownToronto_merged['Cluster Labels'] == 3, DowntownToronto_merged.columns[[1] + list(range(5, DowntownToronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 14  Downtown Toronto               3    Airport Food Court
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 14          Airport Gate        Airport Lounge      Airport Terminal
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 14           Yoga Studio   Dumpling Restaurant            Food Court
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 14           Flower Shop           Fish Market      Fish & Chips Shop

# %% [markdown]
# ###  The selective venue category for Cluster5 is Culture

# %%
DowntownToronto_merged.loc[DowntownToronto_merged['Cluster Labels'] == 4, DowntownToronto_merged.columns[[1] + list(range(5, DowntownToronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 6  Downtown Toronto               4          Concert Hall
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 6          Liquor Store            Steakhouse                   Pub
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 6    Italian Restaurant    Belgian Restaurant              Beer Bar
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 6   Dumpling Restaurant           Fish Market      Fish & Chips Shop
